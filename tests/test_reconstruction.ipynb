# %%
# %matplotlib inline

# %%
from pylab import *

# %%
from matplotlib.pyplot import figure, plot, xlabel, ylabel, title, show

# %%
from niftypet import nimpa
# Out:
# i> conda environment found: niftypet

# %%
nimpa.gpuinfo()
# Out:
# [('GeForce GTX 1080 Ti', 11721L, 6L, 1L), ('GeForce GT 730', 1028L, 3L, 5L)]

# %%
from niftypet import nipet
# Out:
# i> conda environment found: niftypet
# /home2/jjlee/PycharmProjects/NIPET/niftypet/nipet/lm/pviews.py:9: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/home2/jjlee/anaconda2/envs/niftypet/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/home2/jjlee/anaconda2/envs/niftypet/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/home2/jjlee/anaconda2/envs/niftypet/lib/python2.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home2/jjlee/anaconda2/envs/niftypet/lib/python2.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home2/jjlee/anaconda2/envs/niftypet/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 499, in start
#     self.io_loop.start()
#   File "/home2/jjlee/anaconda2/envs/niftypet/lib/python2.7/site-packages/tornado/ioloop.py", line 1073, in start
#     handler_func(fd_obj, events)
#   File "/home2/jjlee/anaconda2/envs/niftypet/lib/python2.7/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home2/jjlee/anaconda2/envs/niftypet/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/home2/jjlee/anaconda2/envs/niftypet/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home2/jjlee/anaconda2/envs/niftypet/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/home2/jjlee/anaconda2/envs/niftypet/lib/python2.7/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home2/jjlee/anaconda2/envs/niftypet/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home2/jjlee/anaconda2/envs/niftypet/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home2/jjlee/anaconda2/envs/niftypet/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home2/jjlee/anaconda2/envs/niftypet/lib/python2.7/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home2/jjlee/anaconda2/envs/niftypet/lib/python2.7/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home2/jjlee/anaconda2/envs/niftypet/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2724, in run_cell
#     self.events.trigger('post_run_cell')
#   File "/home2/jjlee/anaconda2/envs/niftypet/lib/python2.7/site-packages/IPython/core/events.py", line 74, in trigger
#     func(*args, **kwargs)
#   File "/home2/jjlee/anaconda2/envs/niftypet/lib/python2.7/site-packages/ipykernel/pylab/backend_inline.py", line 164, in configure_once
#     activate_matplotlib(backend)
#   File "/home2/jjlee/anaconda2/envs/niftypet/lib/python2.7/site-packages/IPython/core/pylabtools.py", line 315, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/home2/jjlee/anaconda2/envs/niftypet/lib/python2.7/site-packages/matplotlib/pyplot.py", line 231, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/home2/jjlee/anaconda2/envs/niftypet/lib/python2.7/site-packages/matplotlib/__init__.py", line 1422, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/home2/jjlee/anaconda2/envs/niftypet/lib/python2.7/site-packages/matplotlib/backends/__init__.py", line 16, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use("Agg")

# %%
nimpa.gpuinfo(extended=True)
# Out:
# [('GeForce GTX 1080 Ti', 11721L, 6L, 1L), ('GeForce GT 730', 1028L, 3L, 5L)]
# [('GeForce GTX 1080 Ti', 11721L, 6L, 1L), ('GeForce GT 730', 1028L, 3L, 5L)]

# %%
mMRparams = nipet.get_mmrparams()

# %%
mMRparams['Cnt']['VERBOSE'] = True

# %%
folderin = '/home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC'

# %%
datain = nipet.classify_input(folderin, mMRparams)
# Out:
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame40.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame35.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame43.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame25.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame50.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame42.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame51.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame54.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame47.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame2.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame58.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame22.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame18.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame20.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame67.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame59.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame33.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame6.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame65.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame16.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame15.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame66.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame9.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame39.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame52.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame34.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame60.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame72.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame26.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame46.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame55.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame11.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame61.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame10.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/fdgv1.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame28.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame14.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame8.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame24.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame23.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame36.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame70.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame69.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame62.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame31.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame27.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame49.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame48.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame3.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame63.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame19.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame21.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame56.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame13.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame29.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame17.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame57.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame68.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame45.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame71.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame7.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame4.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame64.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame5.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame12.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame30.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame44.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame1.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame37.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame53.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame32.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame38.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame41.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/reconstructed/FDGv1_frame0.nii.gz
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/umap/NP995-24.MR.CCIR-00500_CCIR-00559_Arbeleaz.98.90.20181005.102206.14t628k.dcm
#    Image Type: ['DERIVED', 'PRIMARY', 'M', 'NORM', 'IN_PHASE', 'DIS3D', 'DIS2D', 'MRPET_UMAP3D']
#    Comments: uMap
#    TR: 4.14
#    TE: 2.51
#
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/umap/NP995-24.MR.CCIR-00500_CCIR-00559_Arbeleaz.98.100.20181005.102206.15dczn7.dcm
#    Image Type: ['DERIVED', 'PRIMARY', 'M', 'NORM', 'IN_PHASE', 'DIS3D', 'DIS2D', 'MRPET_UMAP3D']
#    Comments: uMap
#    TR: 4.14
#    TE: 2.51
#
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/umap/NP995-24.MR.CCIR-00500_CCIR-00559_Arbeleaz.98.50.20181005.102206.2p8rll.dcm
#    Image Type: ['DERIVED', 'PRIMARY', 'M', 'NORM', 'IN_PHASE', 'DIS3D', 'DIS2D', 'MRPET_UMAP3D']
#    Comments: uMap
#    TR: 4.14
#    TE: 2.51
#
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/umap/NP995-24.MR.CCIR-00500_CCIR-00559_Arbeleaz.98.3.20181005.102206.1hrrb3i.dcm
#    Image Type: ['DERIVED', 'PRIMARY', 'M', 'NORM', 'IN_PHASE', 'DIS3D', 'DIS2D', 'MRPET_UMAP3D']
#    Comments: uMap
#    TR: 4.14
#    TE: 2.51
#
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/umap/NP995-24.MR.CCIR-00500_CCIR-00559_Arbeleaz.98.18.20181005.102206.1nrsasn.dcm
#    Image Type: ['DERIVED', 'PRIMARY', 'M', 'NORM', 'IN_PHASE', 'DIS3D', 'DIS2D', 'MRPET_UMAP3D']
#    Comments: uMap
#    TR: 4.14
#    TE: 2.51
#
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/umap/NP995-24.MR.CCIR-00500_CCIR-00559_Arbeleaz.98.67.20181005.102206.16kb9ej.dcm
#    Image Type: ['DERIVED', 'PRIMARY', 'M', 'NORM', 'IN_PHASE', 'DIS3D', 'DIS2D', 'MRPET_UMAP3D']
#    Comments: uMap
#    TR: 4.14
#    TE: 2.51
#
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/umap/NP995-24.MR.CCIR-00500_CCIR-00559_Arbeleaz.98.59.20181005.102206.1e9fmkn.dcm
#    Image Type: ['DERIVED', 'PRIMARY', 'M', 'NORM', 'IN_PHASE', 'DIS3D', 'DIS2D', 'MRPET_UMAP3D']
#    Comments: uMap
#    TR: 4.14
#    TE: 2.51
#
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/umap/NP995-24.MR.CCIR-00500_CCIR-00559_Arbeleaz.98.71.20181005.102206.qj22q8.dcm
#    Image Type: ['DERIVED', 'PRIMARY', 'M', 'NORM', 'IN_PHASE', 'DIS3D', 'DIS2D', 'MRPET_UMAP3D']
#    Comments: uMap
#    TR: 4.14
#    TE: 2.51
#
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/umap/NP995-24.MR.CCIR-00500_CCIR-00559_Arbeleaz.98.107.20181005.102206.1fwugrk.dcm
#    Image Type: ['DERIVED', 'PRIMARY', 'M', 'NORM', 'IN_PHASE', 'DIS3D', 'DIS2D', 'MRPET_UMAP3D']
#    Comments: uMap
#    TR: 4.14
#    TE: 2.51
#
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/umap/NP995-24.MR.CCIR-00500_CCIR-00559_Arbeleaz.98.82.20181005.102206.f3mec8.dcm
#    Image Type: ['DERIVED', 'PRIMARY', 'M', 'NORM', 'IN_PHASE', 'DIS3D', 'DIS2D', 'MRPET_UMAP3D']
#    Comments: uMap
#    TR: 4.14
#    TE: 2.51
#
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/umap/NP995-24.MR.CCIR-00500_CCIR-00559_Arbeleaz.98.64.20181005.102206.197tcb3.dcm
#    Image Type: ['DERIVED', 'PRIMARY', 'M', 'NORM', 'IN_PHASE', 'DIS3D', 'DIS2D', 'MRPET_UMAP3D']
#    Comments: uMap
#    TR: 4.14
#    TE: 2.51
#
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/umap/NP995-24.MR.CCIR-00500_CCIR-00559_Arbeleaz.98.83.20181005.102206.w457lp.dcm
#    Image Type: ['DERIVED', 'PRIMARY', 'M', 'NORM', 'IN_PHASE', 'DIS3D', 'DIS2D', 'MRPET_UMAP3D']
#    Comments: uMap
#    TR: 4.14
#    TE: 2.51
#
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/umap/NP995-24.MR.CCIR-00500_CCIR-00559_Arbeleaz.98.11.20181005.102206.7943qr.dcm
#    Image Type: ['DERIVED', 'PRIMARY', 'M', 'NORM', 'IN_PHASE', 'DIS3D', 'DIS2D', 'MRPET_UMAP3D']
#    Comments: uMap
#    TR: 4.14
#    TE: 2.51
#
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/umap/NP995-24.MR.CCIR-00500_CCIR-00559_Arbeleaz.98.112.20181005.102206.q6cyv.dcm
#    Image Type: ['DERIVED', 'PRIMARY', 'M', 'NORM', 'IN_PHASE', 'DIS3D', 'DIS2D', 'MRPET_UMAP3D']
#    Comments: uMap
#    TR: 4.14
#    TE: 2.51
#
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/umap/NP995-24.MR.CCIR-00500_CCIR-00559_Arbeleaz.98.121.20181005.102206.1modrhk.dcm
#    Image Type: ['DERIVED', 'PRIMARY', 'M', 'NORM', 'IN_PHASE', 'DIS3D', 'DIS2D', 'MRPET_UMAP3D']
#    Comments: uMap
#    TR: 4.14
#    TE: 2.51
#
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/umap/NP995-24.MR.CCIR-00500_CCIR-00559_Arbeleaz.98.97.20181005.102206.6ryupi.dcm
#    Image Type: ['DERIVED', 'PRIMARY', 'M', 'NORM', 'IN_PHASE', 'DIS3D', 'DIS2D', 'MRPET_UMAP3D']
#    Comments: uMap
#    TR: 4.14
#    TE: 2.51
#
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/umap/NP995-24.MR.CCIR-00500_CCIR-00559_Arbeleaz.98.54.20181005.102206.pxfybc.dcm
#    Image Type: ['DERIVED', 'PRIMARY', 'M', 'NORM', 'IN_PHASE', 'DIS3D', 'DIS2D', 'MRPET_UMAP3D']
#    Comments: uMap
#    TR: 4.14
#    TE: 2.51
#
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/umap/NP995-24.MR.CCIR-00500_CCIR-00559_Arbeleaz.98.77.20181005.102206.rpupwe.dcm
#    Image Type: ['DERIVED', 'PRIMARY', 'M', 'NORM', 'IN_PHASE', 'DIS3D', 'DIS2D', 'MRPET_UMAP3D']
#    Comments: uMap
#    TR: 4.14
#    TE: 2.51
#
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/umap/NP995-24.MR.CCIR-00500_CCIR-00559_Arbeleaz.98.128.20181005.102206.1s31n2o.dcm
#    Image Type: ['DERIVED', 'PRIMARY', 'M', 'NORM', 'IN_PHASE', 'DIS3D', 'DIS2D', 'MRPET_UMAP3D']
#    Comments: uMap
#    TR: 4.14
#    TE: 2.51
#
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/umap/NP995-24.MR.CCIR-00500_CCIR-00559_Arbeleaz.98.4.20181005.102206.1sdoutc.dcm
#    Image Type: ['DERIVED', 'PRIMARY', 'M', 'NORM', 'IN_PHASE', 'DIS3D', 'DIS2D', 'MRPET_UMAP3D']
#    Comments: uMap
#    TR: 4.14
#    TE: 2.51
#
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/umap/NP995-24.MR.CCIR-00500_CCIR-00559_Arbeleaz.98.24.20181005.102206.122la0.dcm
#    Image Type: ['DERIVED', 'PRIMARY', 'M', 'NORM', 'IN_PHASE', 'DIS3D', 'DIS2D', 'MRPET_UMAP3D']
#    Comments: uMap
#    TR: 4.14
#    TE: 2.51
#
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/umap/NP995-24.MR.CCIR-00500_CCIR-00559_Arbeleaz.98.35.20181005.102206.17ph53m.dcm
#    Image Type: ['DERIVED', 'PRIMARY', 'M', 'NORM', 'IN_PHASE', 'DIS3D', 'DIS2D', 'MRPET_UMAP3D']
#    Comments: uMap
#    TR: 4.14
#    TE: 2.51
#
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/umap/NP995-24.MR.CCIR-00500_CCIR-00559_Arbeleaz.98.43.20181005.102206.1yrj400.dcm
#    Image Type: ['DERIVED', 'PRIMARY', 'M', 'NORM', 'IN_PHASE', 'DIS3D', 'DIS2D', 'MRPET_UMAP3D']
#    Comments: uMap
#    TR: 4.14
#    TE: 2.51
#
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/umap/NP995-24.MR.CCIR-00500_CCIR-00559_Arbeleaz.98.108.20181005.102206.egh90s.dcm
#    Image Type: ['DERIVED', 'PRIMARY', 'M', 'NORM', 'IN_PHASE', 'DIS3D', 'DIS2D', 'MRPET_UMAP3D']
#    Comments: uMap
#    TR: 4.14
#    TE: 2.51
#
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/umap/NP995-24.MR.CCIR-00500_CCIR-00559_Arbeleaz.98.7.20181005.102206.1icccd4.dcm
#    Image Type: ['DERIVED', 'PRIMARY', 'M', 'NORM', 'IN_PHASE', 'DIS3D', 'DIS2D', 'MRPET_UMAP3D']
#    Comments: uMap
#    TR: 4.14
#    TE: 2.51
#
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/umap/NP995-24.MR.CCIR-00500_CCIR-00559_Arbeleaz.98.38.20181005.102206.1ry7fqb.dcm
#    Image Type: ['DERIVED', 'PRIMARY', 'M', 'NORM', 'IN_PHASE', 'DIS3D', 'DIS2D', 'MRPET_UMAP3D']
#    Comments: uMap
#    TR: 4.14
#    TE: 2.51
#
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/umap/NP995-24.MR.CCIR-00500_CCIR-00559_Arbeleaz.98.92.20181005.102206.1b3zn4m.dcm
#    Image Type: ['DERIVED', 'PRIMARY', 'M', 'NORM', 'IN_PHASE', 'DIS3D', 'DIS2D', 'MRPET_UMAP3D']
#    Comments: uMap
#    TR: 4.14
#    TE: 2.51
#
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/umap/NP995-24.MR.CCIR-00500_CCIR-00559_Arbeleaz.98.98.20181005.102206.tj5loz.dcm
#    Image Type: ['DERIVED', 'PRIMARY', 'M', 'NORM', 'IN_PHASE', 'DIS3D', 'DIS2D', 'MRPET_UMAP3D']
#    Comments: uMap
#    TR: 4.14
#    TE: 2.51
#
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/umap/NP995-24.MR.CCIR-00500_CCIR-00559_Arbeleaz.98.74.20181005.102206.ui8keu.dcm
#    Image Type: ['DERIVED', 'PRIMARY', 'M', 'NORM', 'IN_PHASE', 'DIS3D', 'DIS2D', 'MRPET_UMAP3D']
#    Comments: uMap
#    TR: 4.14
#    TE: 2.51
#
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/umap/NP995-24.MR.CCIR-00500_CCIR-00559_Arbeleaz.98
npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-1680-1740.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-2340-2400.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-60-90.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-900-960.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-2280-2340.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-1860-1920.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-1140-1200.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-360-420.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-60-70.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-1380-1440.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-150-180.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-1260-1320.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-840-900.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-70-80.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-2760-2820.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-1920-1980.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-3480-3540.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-50-60.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-1980-2040.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-40-50.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-540-600.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-80-90.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-240-270.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-210-240.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-180-210.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-3240-3300.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-100-110.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-1440-1500.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-0-0.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-2580-2640.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-2520-2580.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-780-840.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-2220-2280.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-420-480.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-3060-3120.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-2880-2940.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-30-60.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-3300-3360.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-30-40.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-960-1020.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-0-10.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-20-30.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-0-30.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-270-300.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-480-540.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-2700-2760.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-2100-2160.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-1740-1800.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-2160-2220.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-1320-1380.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-1800-1860.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-1020-1080.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-1500-1560.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-3180-3240.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-1080-1140.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-2640-2700.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-2040-2100.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-2400-2460.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-3540-3600.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-1560-1620.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-2460-2520.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-720-780.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-2940-3000.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-1200-1260.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-600-660.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-110-120.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-3000-3060.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-300-360.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-660-720.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-10-20.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-3420-3480.npy
# prompt sinogram data.
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/1.3.12.2.1107.5.2.38.51010.30000018100414410813600000029.dcm
#    Image Type: ['ORIGINAL', 'PRIMARY', 'PET_LISTMODE']
#    CSA Data Type: MRPETLM_LARGE
#    Comments: Listmode
# i> got LM interfile.
# i> got CSA info.
#
# --------------------------------------------------------------------------
# i> file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-120-150.npy
# prompt sinogram data.

# %%
datain
# Out:
# {'#mumapDCM': 132,
#  'corepath': '/home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC',
#  'hmumap': '/home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/mumap-hdw/hmumap.npy',
#  'lm_bf': '/home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/1.3.12.2.1107.5.2.38.51010.30000018100414410813600000029.bf',
#  'lm_dcm': '/home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/1.3.12.2.1107.5.2.38.51010.30000018100414410813600000029.dcm',
#  'mumapDCM': '/home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/umap',
#  'nrm_bf': '/home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/norm/1.3.12.2.1107.5.2.38.51010.30000018100414410813600000028.bf',
#  'nrm_dcm': '/home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/norm/1.3.12.2.1107.5.2.38.51010.30000018100414410813600000028.dcm',
#  'sinos': '/home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/LM/sinos_s1_n1_frm-120-150.npy'}

# %%
opth = os.path.join( datain['corepath'], 'output')

# %%
import os

# %%
muhdct = nipet.hdw_mumap(datain, [1,2,4], mMRparams, outpath=opth, use_stored=True)
# Out:
# i> loaded hardware mu-map from file: /home2/jjlee/Local/Pawel/NP995_24/V1/FDG_V1-Converted-AC/mumap-hdw/hmumap.npy

# %%
muodct = nipet.obj_mumap(datain, mMRparams, outpath=opth, store=True)
# Out:
# i> gantry offset: [-0.03004848  0.03503074  0.03607872]
# i> table position origin: [-1223.     0.     0.]
# i> got LM interfile.
# i> got CSA info.

# %%
iz = 60
matshow(muhdct['im'][iz,:,:] + muodct['im'][iz,:,:], cmap='bone')
colorbar()

# %%
hst = nipet.mmrhist(datain, mMRparams)
si = 60
matshow(hst['psino'][si,:,:], cmap='inferno')
colorbar()
xlabel('bins')
ylabel('angles')
matshow(hst['dsino'][si,:,:], cmap='inferno')
colorbar()
xlabel('bins')
ylabel('angles')
# Out:
# i> histograming with span 11 and 1 dynamic frames.
# i> duration by integrating time tags [s]: 3601
# i> centre of mass of axial radiodistribution (filtered with Gaussian of SD = 5 ):  COMPLETED.
# i> dynamic and static buckets single rates:  COMPLETED.
# Text(0,0.5,'angles')

# %%
plot(hst['phc'], label='prompt')
plot(hst['dhc'], label='delayed')
legend()
grid(True)
xlabel('time')
ylabel('counts')
# Out:
# Text(0,0.5,'counts')

# %%
plot(hst['cmass'])
grid(True)
xlabel('time')
ylabel('Center of mass of tracer distribution')
# Out:
# Text(0,0.5,'Center of mass of tracer distribution')

# %%
recon = nipet.mmrchain(
    datain, mMRparams,
    frames = ['fluid', [2400, 3600]],
    mu_h = muhdct,
    mu_o = muodct,
    itr = 4,
    fwhm = 0.0,
    outpath = opth,
    fcomment = 'FDG_V1-AC-last20min',
    store_img = True)
# Out:
# i> using object mu-map from dictionary.
# i> using hardware mu-map from dictionary.
# i> using the provided mu-map the same way for all frames.
# i> dynamic frame times t0, t1: 2400 3600
# i> histograming with span 11 and 1 dynamic frames.
# i> duration by integrating time tags [s]: 3601
# i> centre of mass of axial radiodistribution (filtered with Gaussian of SD = 5 ):  COMPLETED.
# i> dynamic and static buckets single rates:  COMPLETED.
# i> reconstruction in mode 3
# i> # of dynamic frames: 1
# >------ OSEM ( 4 ) -------
# i> got LM interfile.
# i> got CSA info.
#
# --------------- itr-0/4 ---------------
# /home2/jjlee/anaconda2/envs/niftypet/lib/python2.7/site-packages/scipy/ndimage/interpolation.py:583: UserWarning: From scipy 0.13.0, the output shape of zoom() is calculated with round() instead of int() - for these inputs the size of the returned array has changed.
#   "the returned array has changed.", UserWarning)
# i> total scatter sum: 5.0517335
# i> scatter sinogram interpolation...
# i>  0 sinograms interpolated
# i>  100 sinograms interpolated
# i>  200 sinograms interpolated
# i>  300 sinograms interpolated
# i>  400 sinograms interpolated
# i>  500 sinograms interpolated
# i>  600 sinograms interpolated
# i>  700 sinograms interpolated
# i>  800 sinograms interpolated
# i> scatter time: 1394.91825604
#
# --------------- itr-1/4 ---------------
# i> total scatter sum: 4.0704203
# i> scatter sinogram interpolation...
# i>  0 sinograms interpolated
# i>  100 sinograms interpolated
# i>  200 sinograms interpolated
# i>  300 sinograms interpolated
# i>  400 sinograms interpolated
# i>  500 sinograms interpolated
# i>  600 sinograms interpolated
# i>  700 sinograms interpolated
# i>  800 sinograms interpolated
# i> scatter time: 1351.76189899
#
# --------------- itr-2/4 ---------------
# i> total scatter sum: 4.0812798
# i> scatter sinogram interpolation...
# i>  0 sinograms interpolated
# i>  100 sinograms interpolated
# i>  200 sinograms interpolated
# i>  300 sinograms interpolated
# i>  400 sinograms interpolated
# i>  500 sinograms interpolated
# i>  600 sinograms interpolated
# i>  700 sinograms interpolated
# i>  800 sinograms interpolated
# i> scatter time: 1402.63729501
#
# --------------- itr-3/4 ---------------
# i> recon time: 5809.07726192
# i> applying decay correction 1.3703403655921707
# i> applying quantification factor 15856.9458807 to the whole image for the frame duration of : 1200

# %%
matshow(recon['im'][60,:,:], cmap='magma')
colorbar()
